# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/gauravn/Downloads/archive/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.rename(columns={'SepalLengthCm':'SL','SepalWidthCm':'SW','PetalLengthCm':'PL','PetalWidthCm':'PW'},inplace=True)

# %%
df.head()
# Out:
#    Id   SL   SW   PL   PW      Species
# 0   1  5.1  3.5  1.4  0.2  Iris-setosa
# 1   2  4.9  3.0  1.4  0.2  Iris-setosa
# 2   3  4.7  3.2  1.3  0.2  Iris-setosa
# 3   4  4.6  3.1  1.5  0.2  Iris-setosa
# 4   5  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris_setosa = df[df['Species'] == 'Iris-setosa']
iris_versicolor = df[df['Species'] == 'Iris-versicolor']
iris_virginica = df[df['Species'] == 'Iris-virginica']

# %%
print(iris_setosa['SW'].mean())
print(iris_versicolor['SW'].mean())
print(iris_virginica['SW'].mean())
# Out:
# 3.4180000000000006
# 2.7700000000000005
# 2.9739999999999998

# %%
print(iris_setosa['PW'].median())
print(iris_versicolor['PW'].median())
print(iris_virginica['PW'].median())
# Out:
# 0.2
# 1.3
# 2.0

# %%
pd.options.display.max_rows=200

# %%
df
# Out:
#       Id   SL   SW   PL   PW          Species
# 0      1  5.1  3.5  1.4  0.2      Iris-setosa
# 1      2  4.9  3.0  1.4  0.2      Iris-setosa
# 2      3  4.7  3.2  1.3  0.2      Iris-setosa
# 3      4  4.6  3.1  1.5  0.2      Iris-setosa
# 4      5  5.0  3.6  1.4  0.2      Iris-setosa
# 5      6  5.4  3.9  1.7  0.4      Iris-setosa
# 6      7  4.6  3.4  1.4  0.3      Iris-setosa
# 7      8  5.0  3.4  1.5  0.2      Iris-setosa
# 8      9  4.4  2.9  1.4  0.2      Iris-setosa
# 9     10  4.9  3.1  1.5  0.1      Iris-setosa
# 10    11  5.4  3.7  1.5  0.2      Iris-setosa
# 11    12  4.8  3.4  1.6  0.2      Iris-setosa
# 12    13  4.8  3.0  1.4  0.1      Iris-setosa
# 13    14  4.3  3.0  1.1  0.1      Iris-setosa
# 14    15  5.8  4.0  1.2  0.2      Iris-setosa
# 15    16  5.7  4.4  1.5  0.4      Iris-setosa
# 16    17  5.4  3.9  1.3  0.4      Iris-setosa
# 17    18  5.1  3.5  1.4  0.3      Iris-setosa
# 18    19  5.7  3.8  1.7  0.3      Iris-setosa
# ...

# %%
#Range (measures of dispersion)
maximum=np.max(iris_setosa['PL'])
minimum=np.min(iris_setosa['PL'])
print(maximum-minimum)
# Out:
# 0.8999999999999999

# %%
#Variance 
'''print(iris_setosa['PL'].var())
print(iris_versicolor['PL'].var())
print(iris_virginica['PL'].var())
'''
print(np.var(iris_setosa['PL']))
print(np.var(iris_virginica['PL']))
print(np.var(iris_versicolor['PL']))
# Out:
# 0.02950400000000001
# 0.2984960000000002
# 0.21640000000000012

# %%
#Standard deviation
print(iris_setosa['PL'].std())
print(iris_versicolor['PL'].std())
print(iris_virginica['PL'].std())
# Out:
# 0.1735111594364455
# 0.46991097723995806
# 0.5518946956639835

# %%
#Percentiles(QUARTILES) 
print(np.percentile(iris_virginica['PW'],25))#Q1
print(np.percentile(iris_virginica['PW'],50))#Q2
print(np.percentile(iris_virginica['PW'],75))#Q3
print(np.percentile(iris_virginica['PW'],100))#Q4
#the values 1.8,2.0 etx specify the range where the quartile lie. in this case Q1 lies at 0-1.8
#and Q2 lies between 1.9-2.0 and so on
# Out:
# 1.8
# 2.0
# 2.3
# 2.5

# %%
print(np.percentile(iris_virginica['PL'],25))#Q1
print(np.percentile(iris_virginica['PL'],50))#Q2
print(np.percentile(iris_virginica['PL'],75))#Q3
print(np.percentile(iris_virginica['PL'],100))#Q4
# Out:
# 5.1
# 5.55
# 5.875
# 6.9

# %% [markdown]
# PROBABILITY, PERMUTATION, COMBINATION

# %%
#BINOMIAL DISTRIBUTION
import scipy.stats as sp
sp.binom.pmf(4,10,1/2)
# Out:
# 0.2050781249999999

# %%
print(sp.poisson.pmf(4,8))#pmf is used for particular values
print(sp.poisson.cdf(2,8))#cdf(Cummulative distribution frequency) is used of we want to find between or less than the value specified
# Out:
# 0.057252288495362
# 0.013753967744002971

# %%
sp.poisson.pmf(0,8/12)#8/12(8 is the lambda value, 12 is converting the hours to minute)
# Out:
# 0.513417119032592

# %% [markdown]
# SAMPLING TECHNIQUES

# %%
import random
data = [21, 93, 62, 76, 73, 20, 56, 95, 41, 36, 38, 13, 80, 88, 34, 18, 40, 11, 25, 29, 61, 23, 82, 10, 92, 69, 60, 87, 14, 91]
random.sample(data,k=10)#sample is used for sampling without repetition
# Out:
# [20, 34, 93, 80, 11, 82, 41, 14, 21, 87]

# %%
random.choices(data,k=10)#choices is used for sampling with repetition
# Out:
# [23, 88, 61, 10, 13, 62, 92, 62, 20, 29]

# %%
samples = []
for i in range(10):
    samples.append(random.sample(data,k=10))
samples
# Out:
# [[69, 36, 80, 34, 56, 88, 29, 73, 87, 95],
#  [21, 36, 11, 29, 23, 10, 73, 34, 91, 69],
#  [13, 20, 14, 88, 91, 10, 56, 82, 95, 29],
#  [29, 10, 11, 82, 62, 61, 13, 38, 23, 60],
#  [92, 18, 41, 40, 36, 87, 14, 13, 93, 56],
#  [34, 41, 40, 25, 91, 76, 13, 56, 80, 62],
#  [23, 60, 21, 25, 80, 69, 20, 38, 14, 62],
#  [87, 69, 88, 61, 13, 82, 21, 73, 41, 20],
#  [13, 87, 36, 38, 34, 82, 23, 11, 95, 14],
#  [61, 80, 11, 18, 38, 87, 76, 13, 92, 10]]

# %% [markdown]
#                         STRATIFIED SAMPLING

# %%
income = pd.DataFrame({'status':['Low', 'High', 'Below Poverty', 'Middle', 'Low', 'High','Middle', 'Low', 'Middle', 
                                      'High', 'Middle', 'Below Poverty', 'Low', 'Below Poverty', 'High'],
                       'inc':[4850, 9270, 2520, 6020, 5790, 10400, 7140, 3100, 6850, 9740, 6540, 1230, 4400, 2210, 9880]})

# %%
income
# Out:
#            status    inc
# 0             Low   4850
# 1            High   9270
# 2   Below Poverty   2520
# 3          Middle   6020
# 4             Low   5790
# 5            High  10400
# 6          Middle   7140
# 7             Low   3100
# 8          Middle   6850
# 9            High   9740
# 10         Middle   6540
# 11  Below Poverty   1230
# 12            Low   4400
# 13  Below Poverty   2210
# 14           High   9880

# %%
income.status.value_counts()
# Out:
# Low              4
# High             4
# Middle           4
# Below Poverty    3
# Name: status, dtype: int64

# %%
#this line of code groups the data by status and extracts 2 rows from the population as samples
sample = income.groupby('status').apply(lambda x: x.sample(2))
sample
# Out:
#                          status    inc
# status
# Below Poverty 11  Below Poverty   1230
#               2   Below Poverty   2520
# High          1            High   9270
#               5            High  10400
# Low           0             Low   4850
#               4             Low   5790
# Middle        8          Middle   6850
#               10         Middle   6540

# %%
import scipy
import math
math.e
# Out:
# 2.718281828459045

# %% [markdown]
#     HYPOTHESIS TESTING

# %% [markdown]
# Tom is working in a credit card processing company as a team leader. His team is responsible to validate certain data for new credit card applications. The time spent by his team on an application is normally distributed with average 300 minutes and standard deviation 40 minutes.Tom and his team worked on process improvement to reduce the time spent in processing new applications. After implementing the improvements, Tom checked the time spent by his team on randomly selected 25 new card applications. The average time spent is 290 min. Tom is happy that, though it is a small improvement, it is a step in right direction. He shares the good news with his manager Lisa. But Lisa in not convinced about the improvement. At 95% confidence, is the processes really improved?

# %% [markdown]
# Step 1: pop_mean = 300
#         sd = 40
#         sample size(n) =25
#         sample mean = 290
#         confidence  = 95%
#
# Step 2: (Formulate the Hypothesis)
#         Ho (NULL Hypothesis) = pop mean = 300
#         H1 (Alternate Hypothesis) = pop mean < 300

# %%
z = ((290-300)/(40/np.sqrt(25)))
z
# Z value is just a statistic. after find the Z value we need to find the critical value.
# Out:
# -1.25

# %%
cv = sp.norm.ppf(0.05,0,1) # ppf(q,loc=0,scale=1). scale and loc is fixed. q(significance value) is variable
cv
#critical value decides the tail or the significance to accept or reject the Ho. since z > cv accept Ho.
# Out:
# -1.6448536269514729

# %%
#using p-value
p_value = sp.norm.sf(abs(z))
p_value
# Out:
# 0.10564977366685535

# %% [markdown]
# ANOVA(ANALYSIS OF VARIANCE):
#     uses a f value. it computes the f-value and compares it with a critical value as same as before.
